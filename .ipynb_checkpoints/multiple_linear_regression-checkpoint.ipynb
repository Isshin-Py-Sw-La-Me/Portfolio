# %%
# !wget http://pythondatascience.plavox.info/wp-content/uploads/2016/07/winequality-red.csv
# Out:
# --2022-04-20 21:23:02--  http://pythondatascience.plavox.info/wp-content/uploads/2016/07/winequality-red.csv
# pythondatascience.plavox.info (pythondatascience.plavox.info) をDNSに問いあわせています... 54.168.155.129, 18.180.82.32
# pythondatascience.plavox.info (pythondatascience.plavox.info)|54.168.155.129|:80 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 301 Moved Permanently
# 場所: https://pythondatascience.plavox.info/wp-content/uploads/2016/07/winequality-red.csv [続く]
# --2022-04-20 21:23:02--  https://pythondatascience.plavox.info/wp-content/uploads/2016/07/winequality-red.csv
# pythondatascience.plavox.info (pythondatascience.plavox.info)|54.168.155.129|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 200 OK
# 長さ: 84199 (82K) [application/octet-stream]
# `winequality-red.csv' に保存中
#
# winequality-red.csv 100%[===================>]  82.23K  --.-KB/s 時間 0.02s
#
# 2022-04-20 21:23:02 (5.35 MB/s) - `winequality-red.csv' へ保存完了 [84199/84199]

# %%
import pandas as pd

df = pd.read_csv('winequality-red.csv', sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# xに説明変数全体、x1に密度(density)、x2に揮発酸、yにアルコール度数
x = df[['density', 'volatile acidity']]
y = df[['alcohol']]
x1 = df[['density']]
x2 = df[['volatile acidity']]

print(x.shape)
print(y.shape)
# Out:
# (1599, 2)
# (1599, 1)

# %%
from mpl_toolkits.mplot3d import Axes3D  #3Dplot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig = plt.figure()
ax = Axes3D(fig)

ax.scatter3D(x1,x2,y)
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_zlabel("y")

plt.show()

# %%
from sklearn import preprocessing
#正規化
mm = preprocessing.MinMaxScaler()
l_2d_min_max = mm.fit_transform(x)

# %%
sscaler = preprocessing.StandardScaler()
xss_sk = sscaler.fit_transform(x)
yss_sk = sscaler.fit_transform(y)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

model_lr = LinearRegression()
model_lr.fit(x,y)
# Out:
# LinearRegression()

# %%
fig = plt.figure()
ax=Axes3D(fig)

ax.scatter3D(x1,x2,y)
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_zlabel("y")
# Out:
# Text(0.5, 0, 'y')
