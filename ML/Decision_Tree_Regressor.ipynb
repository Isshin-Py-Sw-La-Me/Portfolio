# %%
import matplotlib.pyplot as plt
from dtreeviz.trees import *
from dtreeviz.trees import dtreeviz
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 from sklearn.tree import DecisionTreeRegressor
#       2 from sklearn.datasets import make_regression
# ----> 3 from dtreeviz.trees import *
#       5 import matplotlib.pyplot as plt
#       6 from mpl_toolkits.mplot3d import Axes3D
#
# ModuleNotFoundError: No module named 'dtreeviz'

# %%
# !pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Downloading dtreeviz-1.4.1-py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: graphviz>=0.9 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from dtreeviz) (0.20)
# Requirement already satisfied: pytest in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from dtreeviz) (7.1.2)
# Requirement already satisfied: numpy in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from dtreeviz) (1.21.5)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pandas in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from dtreeviz) (1.4.2)
# Requirement already satisfied: scikit-learn in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from dtreeviz) (1.0.2)
# Requirement already satisfied: matplotlib in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from dtreeviz) (3.5.1)
# Requirement already satisfied: packaging>=20.0 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from matplotlib->dtreeviz) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from matplotlib->dtreeviz) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from matplotlib->dtreeviz) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from matplotlib->dtreeviz) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from matplotlib->dtreeviz) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from matplotlib->dtreeviz) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: six>=1.5 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from pandas->dtreeviz) (2022.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from pytest->dtreeviz) (21.4.0)
# Requirement already satisfied: iniconfig in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from pytest->dtreeviz) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from pytest->dtreeviz) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from pytest->dtreeviz) (1.2.2)
# Requirement already satisfied: joblib>=0.11 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from scikit-learn->dtreeviz) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from scikit-learn->dtreeviz) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/isshintoyonaga/.anyenv/envs/pyenv/versions/anaconda3-2022.05/lib/python3.9/site-packages (from scikit-learn->dtreeviz) (2.2.0)
# Installing collected packages: colour, dtreeviz
# Successfully installed colour-0.1.5 dtreeviz-1.4.1

# %%
import matplotlib.pyplot as plt
from dtreeviz.trees import *
from dtreeviz.trees import dtreeviz
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor

# %%
X, y = make_regression(n_samples=100, n_features=2, random_state=777)
plt.figure(figsize=(10, 10))
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
X.shape, y.shape
# Out:
# ((100, 2), (100,))

# %%
tree = DecisionTreeRegressor(max_depth=3)

# %%
model = tree.fit(X, y)
viz = dtreeviz(tree, X, y, target_name="y")
viz.save("./regression_tree.svg")

# %%
from IPython.display import SVG

SVG(filename="regression_tree.svg")
