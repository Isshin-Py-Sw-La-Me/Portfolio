# %% [markdown]
# <h1> 決定株の理解

# %% [markdown]
# ![スクリーンショット 2022-12-13 23.52.19.png](attachment:dd780cca-882b-4e4e-85ea-ec1ea5361dd6.png)

# %% [markdown]
# ![スクリーンショット 2022-12-13 23.52.45.png](attachment:e04beaf5-2e3b-4028-a31d-df5385c7c181.png)

# %% [markdown]
# ![スクリーンショット 2022-12-13 23.53.16.png](attachment:a20b7943-aa1a-4d24-9a33-18d0ac02af14.png)

# %% [markdown]
# ![スクリーンショット 2022-12-13 23.55.04.png](attachment:d61e3b66-720c-4280-a02d-5e59c8fb26a2.png)

# %% [markdown]
# ![スクリーンショット 2022-12-13 23.55.33.png](attachment:d11c1829-f8dd-45a2-bf16-7b58051b21a6.png)

# %% [markdown]
# すべての基本モデルは、最終的な予測で同等の発言権を持っているわけではありません。<br>
# モデルに与えられる優先順位は、モデルに割り当てられた重みによって異なります。<br>
# 基本モデルは相互に依存しています。前のモデルのエラーに応じて、1つの基本モデルが作成されます。Adaboostは切り株の森とも言える。

# %% [markdown]
# ![image.jpeg](attachment:3a2b580d-075d-4944-8bbf-2c5296961453.jpeg)

# %% [markdown]
# ![image.jpeg](attachment:45408870-62ec-4590-8ced-9edd863a3069.jpeg)

# %% [markdown]
# 予測: それぞれの学習器の予測結果に、それぞれの学習器の重みをかけた値で加重平均（多数決）を取り、予測結果とする。

# %%
from sklearn import datasets, metrics
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
iris = datasets.load_iris()

# %%
X = iris.data

# %%
y = iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf = AdaBoostClassifier(n_estimators=50, learning_rate=1)
model = clf.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9555555555555556

# %%
clf2 = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1))
model2 = clf2.fit(X_train, y_train)
y_pred2 = model2.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, y_pred2))
# Out:
# 0.9555555555555556
