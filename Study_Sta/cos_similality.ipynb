# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import spatial

# %%
def cos_sim(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

# %%
data1 = [90.0 * np.sin(i / 2) + np.random.rand() for i in range(30)]
data2 = [200.0 * np.sin(i / 2) + np.random.rand() for i in range(30)]
# data3 = [data1[i] + 100 for i in range(30)]
data3 = [90.0 * np.sin(i / 2.3) + np.random.rand() for i in range(30)]

print(data1)
print(data2)
print(data3)

data_1_2_euclide = np.linalg.norm(np.array(data1) - np.array(data2))
data_1_2_cos_sim = cos_sim(np.array(data1), np.array(data2))

data_1_3_euclide = np.linalg.norm(np.array(data1) - np.array(data3))
data_1_3_cos_sim = cos_sim(np.array(data1), np.array(data3))

plt.figure(figsize=(12, 4))
plt.title(
    "Euclid: D(data1, data3) = {} > D(data1, data2) = {}\nCos_sim: D(data1, data3) = {} < D(data1, data2) = {}".format(
        data_1_3_euclide, data_1_2_euclide, data_1_3_cos_sim, data_1_2_cos_sim
    )
)
plt.plot(data1, label="data1")
plt.plot(data2, label="data2")
plt.plot(data3, label="data3")
plt.legend()
# Out:
# [0.020266956105563394, 43.36615529726803, 76.71765339565873, 90.07737212671276, 82.81569302086203, 54.267386867295926, 13.361143720744955, -30.94332923731781, -67.74285918184128, -87.46167390026494, -85.38253330185051, -62.72612593111168, -24.30097024659399, 20.132424549292764, 59.62437223179674, 84.78470077365436, 89.07788694175201, 72.71621781976282, 37.91924089009775, -5.866360797760649, -48.515568792148194, -78.46080691034153, -89.99323476697629, -78.13656604245796, -48.11860699200313, -5.916910989643176, 37.96529279935614, 72.92844921845669, 89.40366745280323, 84.29950908644975]
# [0.6779280779136588, 95.93990255727152, 169.0549574962942, 200.16303968392972, 182.6290676086528, 120.5829275968439, 28.391864563945813, -69.62613450059989, -150.4878784984007, -195.23928952942114, -191.20096837251197, -140.2029960921911, -55.28218732939154, 43.90455910772245, 131.8120316696388, 187.64707545320445, 198.41975178036984, 160.617067880458, 83.24657759174744, -14.14982396392201, -108.44950055375098, -175.826882522174, -199.17962144105326, -175.08948381647753, -106.34278049278296, -12.707629190667518, 84.12485875645478, 160.864105058314, 198.15988973267923, 187.45439400344472]
# [0.7697176837499238, 38.7900877647587, 69.33534931895323, 87.46688609943509, 89.01142899167145, 74.24771470213112, 46.18829379344405, 9.74265937315819, -28.890662231378275, -62.42155035217755, -83.87301349228886, -89.4591029807205, -78.69171214855126, -52.283822746298675, -17.2801574124206, 21.711822030010445, 56.35009215555709, 81.33419297930959, 90.29262097024466, 83.65127368473067, 60.14848282233251, 26.157644097089985, -12.103482652203162, -48.66791121796444, -76.20512119304787, -88.94268110308359, -85.61826733476772, -65.94249512372551, -33.54226937519921, 3.9131162603043737]

# %%
hoge = np.array([1, 2])
foo = np.array([2, 3])
baa = np.array([1, 1])

plt.title(
    "Euclid: D(data1, data3) = {} > D(data1, data2) = {}\nCos_sim: D(data1, data3) = {} < D(data1, data2) = {}".format(
        np.linalg.norm(hoge - baa),
        np.linalg.norm(hoge - foo),
        cos_sim(hoge, baa),
        cos_sim(hoge, foo),
    )
)
plt.plot(hoge, label="data1")
plt.plot(foo, label="data2")
plt.plot(baa, label="data3")
plt.legend()
# print("Cos_similarity: {}".format(cos_sim(hoge, foo)))
# print("Euclid_distance: {}".format(np.linalg.norm(hoge - foo)))
